# %%
# %cd Growing-Neural-Cellular-Automata
# Out:
# /home/pesquisavcl/pesquisa/filipe/automatos/Growing-Neural-Cellular-Automata

# %%
# %matplotlib inline
import time
import imageio
import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from PIL import Image

from IPython.display import clear_output

from lib.CAModel import CAModel, LCAModel, CCAModel, SAModel,mCAModel_v7, mCAModel_v9
from lib.utils_vis import SamplePool, to_alpha, to_rgb, get_living_mask, make_seed, make_circle_masks
import torch
import os

# %%
# def load_emoji(path="C:/Users/andre/OneDrive/Imagens/gato_png.png", target_size=40):
    
#     im = imageio.imread(path, pilmode='RGBA')  
#     emoji = np.array(im.astype(np.float32))
#     emoji = cv2.resize(emoji, (target_size, target_size))
#     emoji /= 255.0
#     return emoji

def load_emoji_v2(path, output_folder, target_size=40 ):

    im = Image.open(path).resize((target_size,target_size))
    # rgb_im = im.convert('RGB')
    rgb_im = im
    path_img_png = os.path.join(output_folder, 'target.png')
    rgb_im.save(path_img_png)
    
    im = imageio.imread(path_img_png, pilmode='RGBA')  
    #im = imageio.imread(path_img_png, pilmode='RGB')  
    im = np.array(im.astype(np.float32))
    # # emoji = cv2.resize(emoji, (target_size, target_size))
    # emoji /= 255.0
    im /= 255.0
    return im


def visualize_batch(x0, x):
    vis0 = to_rgb(x0)
    vis1 = to_rgb(x)
    print('batch (before/after):')
    plt.figure(figsize=[15,5])
    for i in range(x0.shape[0]):
        plt.subplot(2,x0.shape[0],i+1)
        plt.imshow(vis0[i])
        plt.axis('off')
    for i in range(x0.shape[0]):
        plt.subplot(2,x0.shape[0],i+1+x0.shape[0])
        plt.imshow(vis1[i])
        plt.axis('off')
    plt.show()

def plot_loss(loss_log):
    plt.figure(figsize=(10, 4))
    plt.title('Loss history (log10)')
    plt.plot(np.log10(loss_log), '.', alpha=0.1)
    plt.show()

# %%
device = torch.device("cuda:0")
# model_checkpoint_folder = "checkpoint/"

CHANNEL_N = 10   # Number of CA state channels
TARGET_PADDING = 0   # Number of pixels used to pad the target image border
TARGET_SIZE = 40
hidden_size = 8

lr = 2e-3
lr_gamma = 0.9999
betas = (0.5, 0.5)
n_epoch = 200
# n_epoch = 10000

BATCH_SIZE = 8
POOL_SIZE = 1024
CELL_FIRE_RATE = 0.5 #testar com 1.0

#step_min = 64
step_min = 96
# step_max = 96
step_max = 128

loss_type = "mse"
#loss_type = "mae"
# loss_type = "huber"


EXPERIMENT_TYPE = "Growing"

path_input_img = 'data/urso.jpg'

exp_name = "temp"

output_folder = 'outputs'

# %%
# Parameters
exp_name = "coco_gnca_large_ts40_000000004505"
path_input_img = "coco_images/000000004505.jpeg"
CHANNEL_N = 16
TARGET_PADDING = 0
TARGET_SIZE = 40
hidden_size = 40
step_min = 208
step_max = 224
lr = 0.002
lr_gamma = 0.9999
n_epoch = 40000
BATCH_SIZE = 8
POOL_SIZE = 1024
CELL_FIRE_RATE = 0
EXPERIMENT_TYPE = "Growing"
output_folder = "outputs"

# %%
#Dependent parameters

EXPERIMENT_MAP = {"Growing":0, "Persistent":1, "Regenerating":2}
EXPERIMENT_N = EXPERIMENT_MAP[EXPERIMENT_TYPE]

USE_PATTERN_POOL = [0, 1, 1][EXPERIMENT_N]
DAMAGE_N = [0, 0, 3][EXPERIMENT_N]  # Number of patterns to damage in a batch


# exp_name = f"{exp_name}_hs{hidden_size}_ts{TARGET_SIZE}"
output_path = os.path.join(output_folder,exp_name)
                           
if not os.path.exists(output_path): 
    # if the folder directory is not present  
    # then create it. 
    os.makedirs(output_path) 
    
# model_folder = "models/compressNCA_temp1.pth"
model_folder = os.path.join(output_path,'models')

if not os.path.exists(model_folder): 
    # if the folder directory is not present  
    # then create it. 
    os.makedirs(model_folder)

# %%
# model_path = "models/compressNCA_temp1.pth"
#model_path = os.path.join(model_folder,'temp1.pth')
model_path_best = os.path.join(model_folder,'best.pth')
model_path_last = os.path.join(model_folder,'last.pth')

#target_img = load_emoji(path=path_input_img, target_size=TARGET_SIZE)
target_img = load_emoji_v2(path=path_input_img,output_folder=output_path, target_size=TARGET_SIZE)
plt.figure(figsize=(4,4))
print(target_img.shape)
if target_img.shape[2] >3:
    plt.imshow(to_rgb(target_img))
else:
    plt.imshow(target_img)
plt.show()
# Out:
# (40, 40, 4)
# /tmp/ipykernel_845259/310969737.py:17: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread(path_img_png, pilmode='RGBA')

# %%
_25425p = TARGET_PADDING
pad_target = np.pad(target_img, [(_25425p, _25425p), (_25425p, _25425p), (0, 0)])
h, w = pad_target.shape[:2]
pad_target = np.expand_dims(pad_target, axis=0)

#Filipe update
# pad_target = torch.from_numpy(pad_target.astype(np.float32)).to(device) #
pad_target = torch.from_numpy(np.repeat(pad_target, BATCH_SIZE, axis=0).astype(np.float32)).to(device)


seed = make_seed((h, w), CHANNEL_N)
pool = SamplePool(x=np.repeat(seed[None, ...], POOL_SIZE, 0))
batch = pool.sample(BATCH_SIZE).x

ca = mCAModel_v7(CHANNEL_N, CELL_FIRE_RATE, device,hidden_size=hidden_size).to(device)

# mp = "models/remaster_uv71.pth"
# mp = "models/remaster_uv72.pth"
# mp = "models/remaster_uv73.pth"
# ca.load_state_dict(torch.load(mp))

optimizer = optim.Adam(ca.parameters(), lr=lr, betas=betas)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, lr_gamma)

# %%
from torchsummary import summary


# summary(ca, (40, 40, 16))
summary(ca, (TARGET_SIZE, TARGET_SIZE, CHANNEL_N))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1           [-1, 40, 40, 40]           1,960
#             Linear-2           [-1, 40, 40, 16]             640
# ================================================================
# Total params: 2,600
# Trainable params: 2,600
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.68
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.79
# ----------------------------------------------------------------

# %%
# loss_log = []
# best_loss = 9999999
# def train(x, target, steps, optimizer, scheduler, loss_type='mse'):
#     x = ca(x, steps=steps)
#     #import pdb;pdb.set_trace()
#     if target.shape[-1]>3:
#         x_input = x[:, :, :, :4]
#     else:
#         x_input = x[:, :, :, 3]

#     if loss_type=="mse":
#         loss = F.mse_loss(x_input, target)
#     elif loss_type=="mae":
#         loss = F.l1_loss(x_input, target)
#     elif loss_type=="huber":
#         loss = F.huber_loss(x_input, target)

        
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
#     scheduler.step()
#     return x, loss

# def loss_f(x, target):
#     if target.shape[-1]>3:
#         return torch.mean(torch.pow(x[..., :4]-target, 2), [-2,-3,-1])
#     else:
#         return torch.mean(torch.pow(x[..., :3]-target, 2), [-2,-3,-1])

# for i in range(n_epoch+1):

#     if USE_PATTERN_POOL:
#         batch = pool.sample(BATCH_SIZE)
#         x0 = torch.from_numpy(batch.x.astype(np.float32)).to(device)
#         loss_rank = loss_f(x0, pad_target).detach().cpu().numpy().argsort()[::-1]
#         x0 = batch.x[loss_rank]
#         x0[:1] = seed
#         if DAMAGE_N:
#             damage = 1.0-make_circle_masks(DAMAGE_N, h, w)[..., None]
#             x0[-DAMAGE_N:] *= damage
#     else:
#         x0 = np.repeat(seed[None, ...], BATCH_SIZE, 0)
#     x0 = torch.from_numpy(x0.astype(np.float32)).to(device)

#     # x, loss = train(x0, pad_target, np.random.randint(64,96), optimizer, scheduler)
#     x, loss = train(x0, pad_target, np.random.randint(step_min,step_max), optimizer, scheduler, loss_type=loss_type)
    

        
#     if USE_PATTERN_POOL:
#         batch.x[:] = x.detach().cpu().numpy()
#         batch.commit()

#     step_i = len(loss_log)
#     loss_log.append(loss.item())

#     if step_i%100 == 0:
#         clear_output()
#         print(step_i, "loss =", loss.item())
#         visualize_batch(x0.detach().cpu().numpy(), x.detach().cpu().numpy())
#         plot_loss(loss_log)
#         if loss.item() < best_loss:
#             print(f"Saving model... {loss.item()} < {best_loss}") 
#             best_loss = loss.item()
#             #torch.save(ca.state_dict(), model_path)
#             torch.save(ca.state_dict(), model_path_best)
#     if i==(n_epoch-1):
#         torch.save(ca.state_dict(), model_path_last)
# Out:
# 200 loss = 0.016741972416639328
# batch (before/after):
# Saving model... 0.016741972416639328 < 0.027081629261374474

# %% [markdown]
# ## Generate image with inference

# %%
import tqdm

#Best
loaded_ca = mCAModel_v7(CHANNEL_N, CELL_FIRE_RATE, device,hidden_size=hidden_size).to(device)
loaded_ca.load_state_dict(torch.load(model_path_best))

x = np.zeros([1, TARGET_SIZE, TARGET_SIZE, CHANNEL_N], np.float32)

x0 = np.repeat(seed[None, ...], 1, 0)
x0 = torch.from_numpy(x0.astype(np.float32)).to(device)

# xf = loaded_ca(x0,steps=96)
# xf = loaded_ca(x0,steps=step_max)

#Last
loaded_ca = mCAModel_v7(CHANNEL_N, CELL_FIRE_RATE, device,hidden_size=hidden_size).to(device)
loaded_ca.load_state_dict(torch.load(model_path_last))

x = np.zeros([1, TARGET_SIZE, TARGET_SIZE, CHANNEL_N], np.float32)

x0 = np.repeat(seed[None, ...], 1, 0)
x0 = torch.from_numpy(x0.astype(np.float32)).to(device)


xf_last = loaded_ca(x0,steps=step_max)

#Last
loaded_ca = mCAModel_v7(CHANNEL_N, CELL_FIRE_RATE, device,hidden_size=hidden_size).to(device)
loaded_ca.load_state_dict(torch.load(model_path_last))

x0 = xf_last
# x0[:,:,:,:3]=xf_last[:,:,:,:3]
# x0[:,:,:,:4]=xf_last[:,:,:,:4]
# x0[:,3:10,3:10,:3]=0
x0[:,3:10,3:10,5:]=0.0
# x0[:,20:30,20:30,:3]=0
#xf_last = loaded_ca(x0,steps=step_max)
xf_last = loaded_ca(x0,steps=224)
xf = xf_last

# %%
step_max
# Out:
# 224

# %%
#Filipe's code
input_rgb = to_rgb(x0.detach().cpu().numpy())
output_rgb = to_rgb(xf.detach().cpu().numpy())
target_rgb = to_rgb(target_img)

#unpading best
output_image = output_rgb[0]
unpad_output_image = output_image[TARGET_PADDING:output_image.shape[0]-TARGET_PADDING, TARGET_PADDING:output_image.shape[1]-TARGET_PADDING]

#unpading last
output_rgb_last = to_rgb(xf_last.detach().cpu().numpy())
output_image_last = output_rgb_last[0]
unpad_output_image_last = output_image_last[TARGET_PADDING:output_image_last.shape[0]-TARGET_PADDING, TARGET_PADDING:output_image_last.shape[1]-TARGET_PADDING]

plt.figure(figsize=(4,4))
plt.imshow(input_rgb[0])
plt.title("Imagem inicial")

plt.figure(figsize=(4,4))
plt.imshow(unpad_output_image)
plt.title("Imagem automato")

plt.figure(figsize=(4,4))
plt.imshow(to_rgb(target_img))
plt.title("imagem original (rgb)")
plt.show()

# %%
from PIL import Image


path_img_automato_best = os.path.join(output_path, 'automato_best200.png')
# path_img_automato_last = os.path.join(output_path, 'automato_last.png')
# path_original = os.path.join(output_path, 'target.png')

#saving best
unpad_output_image_ = unpad_output_image * 255
unpad_output_image_ = unpad_output_image_.astype(np.uint8)
im = Image.fromarray(unpad_output_image_)
im.save(path_img_automato_best, "PNG")

#saving last
# unpad_output_image_last = unpad_output_image_last * 255
# unpad_output_image_ = unpad_output_image_last.astype(np.uint8)
# im = Image.fromarray(unpad_output_image_)
# im.save(path_img_automato_last, "PNG")


# temp = to_rgb(target_img)* 255
# temp_ = temp.astype(np.uint8)
# im2 = Image.fromarray(temp_)
# # im2 = Image.fromarray(target_img)
# #im2.save("data/target_cca.png", "PNG")
# im2.save(path_original, "PNG")

# %%
from skimage.metrics import mean_squared_error, peak_signal_noise_ratio, structural_similarity
from skimage.io import imread


imagem_automato_best = imread(path_img_automato_best)
imagem_automato_last = imread(path_img_automato_last)
imagem_original = imread(path_original)

mse_best = mean_squared_error(imagem_original, imagem_automato_best)
psnr_best = peak_signal_noise_ratio(imagem_original, imagem_automato_best)
ssim_best = structural_similarity(imagem_original, imagem_automato_best, win_size=3, multichannel=True)

mse_last = mean_squared_error(imagem_original, imagem_automato_last)
psnr_last = peak_signal_noise_ratio(imagem_original, imagem_automato_last)
ssim_last = structural_similarity(imagem_original, imagem_automato_last, win_size=3, multichannel=True)


print("[automato-best]PSNR (Peak Signal-to-Noise Ratio):", psnr_best)
print("[automato-best]MSE (Mean Squared Error):", mse_best)
print("[automato-best]SSIM (Structural Similarity Index):", ssim_best)
print("---")
print("[automato-last]PSNR (Peak Signal-to-Noise Ratio):", psnr_last)
print("[automato-last]MSE (Mean Squared Error):", mse_last)
print("[automato-last]SSIM (Structural Similarity Index):", ssim_last)
print("---")


def tamanho_arquivo(caminho):
    # return os.path.getsize(caminho)
    #print(os.stat(caminho).st_size)
    return os.stat(caminho).st_size



#tamanho_original = tamanho_arquivo(caminho_img_original)
tamanho_original = tamanho_arquivo(path_original)
#tamanho_automato = tamanho_arquivo(caminho_img_automato)
tamanho_automato = tamanho_arquivo(path_img_automato_best)


print("Tamanho da imagem original:", tamanho_original, "bytes")
print("Tamanho da imagem gerada pelo autômato-best:", tamanho_automato, "bytes")

def calcular_bits_por_pixel(caminho_imagem, tamanho_arquivo):
    imagem = imread(caminho_imagem)
    largura, altura, _ = imagem.shape
    total_pixels = largura * altura
    bits_por_pixel = (tamanho_arquivo * 8) / total_pixels
    return bits_por_pixel

#bits_por_pixel_original = calcular_bits_por_pixel(caminho_img_original, tamanho_original)
bits_por_pixel_original = calcular_bits_por_pixel(path_original, tamanho_original)
#bits_por_pixel_automato = calcular_bits_por_pixel(caminho_img_automato, tamanho_automato)
bits_por_pixel_automato = calcular_bits_por_pixel(path_img_automato_best, tamanho_automato)

print("Bits por Pixel da imagem original:", bits_por_pixel_original)
print("Bits por Pixel da imagem gerada pelo autômato-best:", bits_por_pixel_automato)



# Calculando jpeg para comparação
print("#"*10)
print("\nJPEG...")

from PIL import Image

size = TARGET_SIZE
path_input_img
im = Image.open(path_input_img).resize((size,size))
rgb_im = im.convert('RGB')
path_img_jpg = os.path.join(output_path, 'jpeg.jpg')
rgb_im.save(path_img_jpg, quality=95)
imagem_jpeg = imread(path_img_jpg)

mse = mean_squared_error(imagem_original, imagem_jpeg)
psnr = peak_signal_noise_ratio(imagem_original, imagem_jpeg)
ssim = structural_similarity(imagem_original, imagem_jpeg, win_size=3, multichannel=True)
tamanho_jpeg = tamanho_arquivo(path_img_jpg)

print("[jpeg]PSNR (Peak Signal-to-Noise Ratio):", psnr)
print("[jpeg]MSE (Mean Squared Error):", mse)
print("[jpeg]SSIM (Structural Similarity Index):", ssim)
print("Tamanho da imagem original:", tamanho_original, "bytes")
print("Tamanho da imagem gerada pelo jpeg:", tamanho_jpeg, "bytes")

# Calculando webP para comparação
print("#"*10)
print("\nWebP...")

im = Image.open(path_input_img).resize((size,size))
path_img_webp = os.path.join(output_path, 'webp.webp')
im.save(path_img_webp, "webp", quality=100)
imagem_webp = imread(path_img_webp)

mse_webp = mean_squared_error(imagem_original, imagem_webp)
psnr_webp = peak_signal_noise_ratio(imagem_original, imagem_webp)
ssim_webp = structural_similarity(imagem_original, imagem_webp, win_size=3, multichannel=True)
tamanho_webp = os.stat(path_img_webp).st_size

print("[webp]PSNR (Peak Signal-to-Noise Ratio):", psnr_webp)
print("[webp]MSE (Mean Squared Error):", mse_webp)
print("[webp]SSIM (Structural Similarity Index):", ssim_webp)
print("Tamanho da imagem original:", tamanho_original, "bytes")
print("Tamanho da imagem gerada pelo webp:", tamanho_webp, "bytes")
# Out:
# [automato-best]PSNR (Peak Signal-to-Noise Ratio): 19.690966287810948
# [automato-best]MSE (Mean Squared Error): 698.20625
# [automato-best]SSIM (Structural Similarity Index): 0.6567596174182666
# ---
# [automato-last]PSNR (Peak Signal-to-Noise Ratio): 18.834866880748052
# [automato-last]MSE (Mean Squared Error): 850.3420833333333
# [automato-last]SSIM (Structural Similarity Index): 0.6284126301531682
# ---
# Tamanho da imagem original: 4111 bytes
# Tamanho da imagem gerada pelo autômato-best: 3667 bytes
# Bits por Pixel da imagem original: 20.555
# Bits por Pixel da imagem gerada pelo autômato-best: 18.335
# ##########
#
# JPEG...
# [jpeg]PSNR (Peak Signal-to-Noise Ratio): 33.28430616417056
# [jpeg]MSE (Mean Squared Error): 30.524583333333332
# [jpeg]SSIM (Structural Similarity Index): 0.9726459839588525
# Tamanho da imagem original: 4111 bytes
# Tamanho da imagem gerada pelo jpeg: 1811 bytes
# ##########
#
# WebP...
# [webp]PSNR (Peak Signal-to-Noise Ratio): 34.43226985587775
# [webp]MSE (Mean Squared Error): 23.434375
# [webp]SSIM (Structural Similarity Index): 0.9824995076809148
# Tamanho da imagem original: 4111 bytes
# Tamanho da imagem gerada pelo webp: 1704 bytes
